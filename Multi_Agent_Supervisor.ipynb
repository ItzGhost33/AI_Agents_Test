# %% [markdown]
# # Langchain

# %%
RESUME_AGENT_PROMPT = (
    "You are a Resume Parsing and Analysis Expert.\n"
    "Your primary responsibility is to extract text from resumes and answer user questions strictly based on the resume content.\n\n"

    "Rules:\n"
    "- ALWAYS use the `resume_parser` tool when a resume file path is provided.\n"
    "- Use ONLY the information found in the parsed resume text.\n"
    "- If the requested information is not present in the resume, clearly say that it is not available.\n"
    "- Do NOT make assumptions or add external knowledge.\n\n"

    "After parsing the resume:\n"
    "- Summarize relevant sections if needed (skills, experience, education, projects).\n"
    "- Answer the user’s question clearly and concisely using resume evidence.\n"
)


GENERAL_PROMPT = (
    "You are a General Question Answering Assistant.\n"
    "Your role is to answer general knowledge, conceptual, or conversational questions.\n\n"

    "Rules:\n"
    "- Use the `general_question_answer` tool to generate responses.\n"
    "- Provide clear, accurate, and easy-to-understand answers.\n"
    "- Keep responses concise unless the user asks for detailed explanations.\n"
    "- Do NOT perform web searches or resume parsing.\n\n"

    "Tone:\n"
    "- Friendly, professional, and helpful.\n"
)


WEB_SEARCH_PROMPT = (
    "You are a Web Search and Information Retrieval Expert.\n"
    "Your role is to search the internet for up-to-date and factual information.\n\n"

    "Rules:\n"
    "- ALWAYS use the `google_search` tool when the user asks for current, real-world, or factual information.\n"
    "- Do NOT answer from prior knowledge without searching.\n"
    "- Prefer recent and reliable sources.\n\n"

    "After retrieving results:\n"
    "- Summarize the most relevant findings clearly.\n"
    "- If multiple sources agree, present a consolidated answer.\n"
    "- If information is uncertain or conflicting, mention it.\n"
)

# %%
import os
from dotenv import load_dotenv  
from langchain_deepseek import ChatDeepSeek


load_dotenv()

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

# Initialize Azure OpenAI model
model = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0.2,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key=DEEPSEEK_API_KEY
    # api_key="...",
    # other params...
)

# %%
from langchain.tools import tool
import os
from dotenv import load_dotenv  
from langchain.agents import create_agent
from PyPDF2 import PdfReader
from docx import Document
from tavily import TavilyClient
from langgraph.checkpoint.memory import InMemorySaver
from langchain_deepseek import ChatDeepSeek
from langchain_apify import ApifyActorsTool



load_dotenv()

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

# Initialize Azure OpenAI model
model = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0.2,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key=DEEPSEEK_API_KEY
    # api_key="...",
    # other params...
)

def extract_text_from_pdf(pdf_path: str) -> str:
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() or ""
    return text

def extract_text_from_docx(docx_path: str) -> str:
    doc = Document(docx_path)
    return "\n".join([paragraph.text for paragraph in doc.paragraphs])



@tool(description="Extracts text from PDF or DOCX resume files.")
def resume_parser(resume_file_path: str):
    if resume_file_path.endswith(".pdf"):
        return extract_text_from_pdf(resume_file_path)
    elif resume_file_path.endswith(".docx"):
        return extract_text_from_docx(resume_file_path)
    else:
        raise ValueError("Unsupported file type")

# Create resume parser agent
resume_parser_agent = create_agent(
    model,
    tools=[resume_parser],
    name="resume_parser_agent",
    system_prompt=RESUME_AGENT_PROMPT
)

@tool(description="Answer general questions")
def general_question_answer(question: str):
    response = model.invoke(question)
    return response.content

# Create general Q&A agent
general_question_answer_agent = create_agent(
    model,
    tools=[general_question_answer],
    name="general_question_answer_agent",
    system_prompt=GENERAL_PROMPT
)

@tool(description="Do a web search based on user queries")
def google_search(query: str):
    return tavily_client.search(query)

# Create Google search agent
google_search_agent = create_agent(
    model,
    tools=[google_search],
    name="google_search_agent",
    system_prompt=WEB_SEARCH_PROMPT
)  



linkedin_tool = ApifyActorsTool("apimaestro/linkedin-jobs-scraper-api")
linkedin_agent = create_agent(
    model,
    tools = [linkedin_tool],
    system_prompt="search likedIn about the given job",
    name="linkedin job search"
)

# %%
@tool(description="Do a web search based on user queries")
def web_searcher(request: str) -> str:
    result = google_search_agent.invoke({
        "messages": [{"role": "user", "content": request}]
    })
    return result["messages"][-1].text


@tool(description="Resume parsor and answer questions")
def resume_expert(request: str) -> str:
    result = resume_parser_agent.invoke({
        "messages": [{"role": "user", "content": request}]
    })
    return result["messages"][-1].text

@tool(description="Ansewering general quetions")
def friend(request: str) -> str:
    result = general_question_answer_agent.invoke({
        "messages": [{"role": "user", "content": request}]
    })
    return result["messages"][-1].text

@tool(description="Search LinkedIn about given job")
def job_searcher(request: str) -> str:
    result = linkedin_agent.invoke({
        "messages": [{"role": "user", "content": request}]
    })
    return result["messages"][-1].text

# %%
SUPERVISOR_PROMPT = (
    "You are a Supervisor Agent responsible for coordinating multiple specialized agents.\n\n"

    "Available tools:\n"
    "- `resume_expert`: Use for resume parsing or resume-based questions.\n"
    "- `web_searcher`: Use for current, factual, or real-world information.\n"
    "- `job_searcher`: Use for LinkedIn job searches.\n"
    "- `friend`: Use for general or conversational questions.\n\n"

    "Instructions:\n"
    "- Analyze the user request carefully.\n"
    "- Select the most appropriate tool or tools.\n"
    "- If the task requires multiple steps, call tools sequentially.\n"
    "- Do NOT answer directly; always rely on tools.\n"
)


supervisor_agent = create_agent(
    model,
    tools=[web_searcher, resume_expert,friend,job_searcher],
    system_prompt=SUPERVISOR_PROMPT,
)

# %%
CV_PATH = "Your path"

query = f"""Based on the given resume
{CV_PATH}
find what latest things he must learn and
Also find 10 latest jobs he can search next.
"""

# query = "Hi, how are you, can you help suggest jobs based on my resume"

for step in supervisor_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# I'll help you analyze the resume and find the latest things to learn as well as job opportunities. Let me start by parsing the resume.
# Tool Calls:
#   resume_expert (call_00_a2gbCCrCgEpAml2EWDXT3Qvg)
#  Call ID: call_00_a2gbCCrCgEpAml2EWDXT3Qvg
#   Args:
#     request: Parse the resume from C://Users//MicroChannel//Downloads//Vegashkar_CV.pdf and provide a comprehensive analysis of the candidate's skills, experience, and current qualifications
# ================================= Tool Message =================================
# Name: resume_expert
#
# Based on the parsed resume, here is a comprehensive analysis of Vegashkar Punyamoorthy's skills, experience, and qualifications:
#
# ## **Candidate Overview**
# **Name:** Vegashkar Punyamoorthy
# **Current Role:** AI/ML Engineer
# **Education:** BSc in Electrical and Electronic Engineering, University of Jaffna (GPA: 3.55/4.0)
# **Experience Level:** Recent graduate with 1+ years of professional experience
#
# ## **Professional Experience Analysis**
#
# ### **Current Role: AI/ML Engineer, Aion Labs (Remote) - Jan 2025 – Present**
# - **Key Projects:**
#   1. **Bountiful AI** - Built a scripture-aligned investment platform using:
#      - Agentic RAG for accurate Q&A
#      - Preference-alignment scoring system for 5,000+ companies
#      - Controversy classification module
#
#   2. **AI-powered Speaker Vetting System** - Developed scalable system with:
#      - Multi-agent AI pipeline for content analysis
#      - 98% hate speech detection accuracy
#      - 96% alignment scoring accuracy using LLMs
#
#   3. **Lyrical AI** - ChatGPT-style brand intelligence platform:
#      - Agentic workflows with planning and social scraping
#      - LoRA fine-tuned RoBERTa sentiment analysis
#      - LangGraph orchestration with LiteLLM management
#
# ### **Previous Experience:**
# 1. **Teaching Assistant, University of Jaffna (Sept 2024 – Dec 2024)**
#    - Research collaboration and student mentorship
#    - Guidance on methodology and analysis
#
# 2. **Data Science Intern, KBSL (Feb 2024 – Jul 2024)**
#    - Developed predictive models with 90% accuracy
#    - Improved existing model accuracy by 10%
#    - Production deployment experience
#
# ## **Technical Skills Assessment**
#
# ### **Core AI/ML Expertise:**
# - **Generative AI:** LangChain, LangGraph, CrewAI, LLMs, RAG, Hugging Face
# - **Machine Learning:** LSTM, DeepAR, Prophet, N-BEATS, Temporal Fusion Transformers
# - **Computer Vision:** YOLO, Vision Transformers, OpenCV, ResNet
# - **Time Series Forecasting:** Extensive experience with multiple models
#
# ### **Programming & Development:**
# - **Primary:** Python (evident from all projects)
# - **Secondary:** C++, SQL, MATLAB, R, Bash, TypeScript, Nuxt
# - **API Development:** FastAPI, Flask
# - **Containerization:** Docker, Kubernetes
#
# ### **Cloud & Infrastructure:**
# - **Azure:** Data Factory (ADF), Databricks
# - **AWS:** Cloud platform experience
# - **Databases:** Vector databases (Pinecone, pgvector), MySQL, Neo4j, MongoDB
#
# ### **Data Engineering:**
# - Data pipeline development on Azure Data Factory
# - Web scraping and OCR capabilities
# - Data analysis with Pandas, NumPy
# - Visualization with Power BI, Tableau
#
# ## **Project Portfolio Highlights**
#
# ### **Recent AI Projects (2025):**
# 1. **AI-Powered Speaker Vetting System** - Production-ready framework for content moderation
# 2. **Bountiful AI** - Dual-feature platform with ethical Q&A and equity screening
# 3. **Lyrical AI** - Multi-agent brand intelligence platform
# 4. **Smart Bee Colony Monitoring** - Deep learning for sound analysis
#
# ### **Earlier Projects:**
# 1. **AI-Powered Procurement Forecasting** - ML-driven system for hotel operations
# 2. **Chronic Kidney Disease Detection** - XGBoost model with 98% accuracy
#
# ## **Strengths & Qualifications**
#
# ### **Key Strengths:**
# 1. **Full-Stack AI Development:** Experience from model development to production deployment
# 2. **Multi-Agent Systems:** Strong expertise in LangGraph and agentic workflows
# 3. **RAG Implementation:** Proven experience with retrieval-augmented generation systems
# 4. **Production Experience:** Real-world deployment of AI systems
# 5. **Cloud Integration:** Azure and AWS experience with scalable architectures
#
# ### **Educational Foundation:**
# - Strong academic background in Electrical Engineering with AI/ML coursework
# - GPA of 3.55/4.0 indicates solid academic performance
# - Relevant coursework includes Machine Learning, AI, Deep Learning, and Statistics
#
# ## **Career Trajectory & Potential**
#
# ### **Current Level:** Mid-level AI/ML Engineer
# ### **Target Roles:** Data Scientist, Machine Learning Engineer, AI Engineer
# ### **Industry Fit:** Tech companies, fintech, healthcare AI, enterprise AI solutions
#
# ## **Recommendations for Next Career Steps**
#
# 1. **Specialization Areas:**
#    - Generative AI and LLM applications
#    - Multi-agent systems development
#    - AI ethics and alignment systems
#
# 2. **Skill Development Opportunities:**
#    - Advanced MLOps practices
#    - Large-scale distributed systems
#    - Specialized domain knowledge in specific industries
#
# 3. **Potential Growth Paths:**
#    - Senior AI/ML Engineer
#    - AI Solutions Architect
#    - Technical Lead for AI projects
#
# ## **Overall Assessment**
# Vegashkar demonstrates strong technical capabilities in modern AI/ML technologies with practical experience in building and deploying production AI systems. The candidate shows particular strength in generative AI applications, multi-agent systems, and end-to-end AI solution development. The combination of solid academic foundation, hands-on project experience, and current professional role positions them well for intermediate to senior AI/ML roles in technology-focused organizations.
# ================================== Ai Message ==================================
#
# Now let me analyze what latest things he should learn based on current industry trends and his existing skill set:
# Tool Calls:
#   web_searcher (call_00_twhEWwlN1Nyp5OilXuKUATIz)
#  Call ID: call_00_twhEWwlN1Nyp5OilXuKUATIz
#   Args:
#     request: latest AI/ML technologies and skills in demand 2025 for machine learning engineers and AI developers
# ================================= Tool Message =================================
# Name: web_searcher
#
# Based on my research, here are the latest AI/ML technologies and skills in demand for 2025 for machine learning engineers and AI developers:
#
# ## **Top Emerging Technologies for 2025:**
#
# ### **1. Small Language Models (SLMs)**
# - **Key models**: Microsoft Phi-3.5, Meta Llama 4, DeepSeek R1, Qwen
# - **Why in demand**: More efficient, cost-effective, and deployable than large models
# - **Enterprise adoption**: Companies are shifting from large LLMs to specialized SLMs
#
# ### **2. AI Agents & Autonomous Systems**
# - **Agentic AI**: Systems that can think, adapt, and execute independently
# - **Multi-agent orchestration**: Coordinating multiple AI agents for complex tasks
# - **NIMs (Neural Interface Modules)**: Standardized AI agent deployment frameworks
#
# ### **3. Advanced RAG Systems (RAG 2.0+)**
# - **Vector databases**: Pinecone, Weaviate, Milvus, Qdrant
# - **Multi-modal RAG**: Combining text, images, audio, and video retrieval
# - **Real-time RAG**: Dynamic knowledge updates and retrieval
#
# ### **4. MLOps & Production AI**
# - **Model deployment & scaling**: Kubernetes, Docker, cloud-native AI
# - **Model monitoring & observability**: MLflow, Weights & Biases, Evidently AI
# - **Automated ML pipelines**: CI/CD for machine learning
#
# ### **5. Multimodal AI**
# - **Cross-modal understanding**: Text-to-image, image-to-text, audio-visual integration
# - **Multimodal foundation models**: Models that process multiple data types simultaneously
#
# ### **6. Edge AI & On-Device AI**
# - **Edge deployment**: Running models on mobile devices, IoT devices
# - **Federated learning**: Privacy-preserving distributed training
# - **Model compression**: Quantization, pruning, distillation
#
# ## **Most In-Demand Skills for 2025:**
#
# ### **Technical Skills:**
# 1. **Generative AI Development**
#    - Prompt engineering & optimization
#    - Fine-tuning LLMs/SLMs
#    - Building with OpenAI, Anthropic, Google Gemini APIs
#
# 2. **MLOps & Production Engineering**
#    - Model deployment and scaling
#    - Monitoring and maintenance
#    - Automated testing and validation
#
# 3. **Data Engineering for AI**
#    - Data pipeline development
#    - Vector database management
#    - Real-time data processing
#
# 4. **Cloud AI Infrastructure**
#    - AWS SageMaker, Azure ML, Google Vertex AI
#    - Cloud-native AI deployment
#    - Serverless AI functions
#
# 5. **AI System Architecture**
#    - Designing scalable AI systems
#    - Microservices for AI
#    - API design and integration
#
# ### **Programming & Frameworks:**
# - **Python** (essential)
# - **PyTorch & TensorFlow**
# - **LangChain, LlamaIndex** (for LLM applications)
# - **FastAPI, Flask** (for API development)
# - **Docker, Kubernetes** (for containerization)
#
# ### **Specialized Knowledge Areas:**
# 1. **AI Ethics & Governance**
#    - Responsible AI development
#    - Bias detection and mitigation
#    - AI safety and alignment
#
# 2. **Domain-Specific AI**
#    - Healthcare AI applications
#    - Financial AI systems
#    - Manufacturing and industrial AI
#
# 3. **Quantum Machine Learning** (emerging)
#    - Quantum algorithms for optimization
#    - Quantum-enhanced ML
#
# ## **Industry Trends Driving Demand:**
#
# 1. **Enterprise AI Adoption**: Companies spending $37B+ on generative AI in 2025
# 2. **Shift from Experimentation to Production**: Focus on deployed, measurable outcomes
# 3. **Cost Optimization**: Moving from expensive LLMs to efficient SLMs
# 4. **Regulatory Compliance**: Growing need for AI governance and ethics
# 5. **Real-time AI**: Demand for low-latency, responsive AI systems
#
# ## **Salary & Job Market Outlook:**
# - **High demand**: AI/ML engineers are among the most sought-after tech roles
# - **Salary growth**: Continued upward trend with specialized skills commanding premium rates
# - **Role evolution**: ML engineers increasingly taking on AI engineering responsibilities
# - **New roles emerging**: AI Governance Specialist, Generative AI Prompt Engineer, AI Agent Developer
#
# The key takeaway for 2025 is that **practical, production-focused skills** are more valuable than theoretical knowledge. Employers want engineers who can build, deploy, and maintain AI systems that deliver real business value.
# ================================== Ai Message ==================================
#
# Now let me search for the latest job opportunities that would be suitable for his profile:
# Tool Calls:
#   job_searcher (call_00_708qOsD81Ygrhr6mOfdwfqb7)
#  Call ID: call_00_708qOsD81Ygrhr6mOfdwfqb7
#   Args:
#     request: Search for latest AI/ML Engineer, Machine Learning Engineer, Data Scientist jobs with Python, LangChain, RAG, LLM experience, remote or hybrid positions
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> Status: RUNNING, Message:
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:46.517Z ACTOR: Pulling container image of build RhIlLCLRQUlGIxd0g from registry.
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:46.521Z ACTOR: Creating container.
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:46.571Z ACTOR: Starting container.
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.743Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.888Z Input: {
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.890Z   keywords: 'AI ML Engineer Machine Learning Engineer Data Scientist Python LangChain RAG LLM',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.892Z   location: 'United States',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.894Z   page_number: 1,
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.896Z   remote: 'remote',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.898Z   sort: 'recent',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.900Z   date_posted: 'week',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.902Z   experienceLevel: '',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.904Z   easy_apply: '',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.906Z   under_10_applicants: '',
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.907Z   limit: 50
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:47.909Z }
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> 2025-12-27T15:13:55.490Z Successfully processed 50 jobs
# [apify.linkedin-jobs-scraper-api runId:dB2RGy4GKFDJKnUQL] -> Status: SUCCEEDED, Message:
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> Status: RUNNING, Message:
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:21.883Z ACTOR: Pulling container image of build RhIlLCLRQUlGIxd0g from registry.
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:21.885Z ACTOR: Creating container.
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:21.986Z ACTOR: Starting container.
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.759Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.932Z Input: {
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.933Z   keywords: 'LangChain RAG LLM Python Machine Learning Engineer Data Scientist',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.933Z   location: 'United States',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.934Z   page_number: 1,
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.935Z   remote: 'hybrid',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.935Z   sort: 'recent',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.936Z   date_posted: 'week',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.936Z   experienceLevel: '',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.937Z   easy_apply: '',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.938Z   under_10_applicants: '',
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.938Z   limit: 50
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:23.939Z }
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> 2025-12-27T15:14:25.140Z Successfully processed 0 jobs
# [apify.linkedin-jobs-scraper-api runId:LdfMNYGOLJwmpcPKF] -> Status: SUCCEEDED, Message:
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> Status: RUNNING, Message:
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:40.954Z ACTOR: Pulling container image of build RhIlLCLRQUlGIxd0g from registry.
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:40.955Z ACTOR: Creating container.
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:40.995Z ACTOR: Starting container.
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.164Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.334Z Input: {
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.335Z   keywords: 'LangChain RAG LLM Python AI Engineer',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.336Z   location: 'United States',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.336Z   page_number: 1,
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.337Z   remote: '',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.337Z   sort: 'recent',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.338Z   date_posted: 'week',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.339Z   experienceLevel: '',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.339Z   easy_apply: '',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.340Z   under_10_applicants: '',
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.341Z   limit: 50
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:42.341Z }
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> 2025-12-27T15:14:43.557Z Successfully processed 0 jobs
# [apify.linkedin-jobs-scraper-api runId:jejKuUC8INRR7o3mM] -> Status: SUCCEEDED, Message:
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> Status: RUNNING, Message:
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:57.726Z ACTOR: Pulling container image of build RhIlLCLRQUlGIxd0g from registry.
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:57.727Z ACTOR: Creating container.
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:57.779Z ACTOR: Starting container.
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.582Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.710Z Input: {
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.711Z   keywords: 'AI Engineer Machine Learning Engineer Data Scientist Python',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.711Z   location: 'United States',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.712Z   page_number: 1,
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.713Z   remote: '',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.713Z   sort: 'recent',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.714Z   date_posted: 'week',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.715Z   experienceLevel: '',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.715Z   easy_apply: '',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.716Z   under_10_applicants: '',
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.717Z   limit: 50
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:14:58.717Z }
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> 2025-12-27T15:15:06.246Z Successfully processed 50 jobs
# [apify.linkedin-jobs-scraper-api runId:etF7ceXKwRawHIwqA] -> Status: SUCCEEDED, Message:
# ================================= Tool Message =================================
# Name: job_searcher
#
# Based on my search results, I found several AI/ML Engineer, Machine Learning Engineer, and Data Scientist positions with Python, LangChain, RAG, and LLM experience in remote or hybrid positions. Here's a summary of the most relevant opportunities:
#
# ## **Top AI/ML Engineer Positions with Your Required Skills:**
#
# ### **1. AI Engineer at kadence**
# - **Salary**: $150K/yr - $180K/yr
# - **Location**: Remote (United States)
# - **Key Skills**: LLMs, agentic workflows, tool-calling, RAG, Python, TypeScript
# - **Description**: Building agent-driven AI systems with LangGraph, AutoGen, CrewAI experience
#
# ### **2. GenAI and Agentic AI Engineer at Arbitration Forums, Inc.**
# - **Salary**: $128.6K/yr - $195.9K/yr
# - **Location**: Remote (United States)
# - **Key Skills**: LLMs, RAG, prompt engineering, Agentic AI frameworks (CrewAI, Azure AI Foundry)
#
# ### **3. Senior Engineer II - AI/ML at Fanatics**
# - **Salary**: $128K/yr - $242K/yr
# - **Location**: Remote (United States)
# - **Key Skills**: AWS Bedrock, LLMs, Python, AI-driven insights, real-time conversational analytics
#
# ### **4. AI/ML VertexAI Engineer at AMISEQ**
# - **Location**: Remote (United States)
# - **Key Skills**: Vertex AI, GCP, Python, model deployment, LLM integration
#
# ### **5. AI Engineer at Powerfront**
# - **Location**: Remote (United States)
# - **Key Skills**: GPT integrations, Tool Calling, Vector Databases, Graph Databases, RAG, Python
#
# ### **6. Senior AI Engineer (Seattle, Washington) at Syndio**
# - **Salary**: $157K/yr - $185K/yr
# - **Location**: Remote (Seattle, WA)
# - **Key Skills**: LLM-based applications, context engineering, Google Gemini, OpenAI, Anthropic APIs
#
# ### **7. AI Engineer - LLMs, Agents & RAG at EY**
# - **Location**: On-site (Nashville, TN)
# - **Key Skills**: LLMs, RAG, Azure OpenAI, LangChain/Semantic Kernel, Azure ML, vector search
#
# ### **8. AI/ML Engineer at ReturnPro**
# - **Location**: On-site (Miami, FL)
# - **Key Skills**: Generative AI, RAG applications, AI agentic frameworks, LLMs, NLP, LangChain, LlamaIndex
#
# ### **9. Machine Learning Engineer at Hirenza**
# - **Location**: Remote (United States)
# - **Key Skills**: Python, machine learning algorithms, statistical modeling, AI frameworks
#
# ### **10. AI/ML Engineer at micro1**
# - **Location**: Remote (United States)
# - **Key Skills**: Python, LLMs, Retrieval-Augmented Generation (RAG), AWS
#
# ## **Key Trends in the Search Results:**
#
# 1. **High Demand for RAG Expertise**: Many positions specifically mention Retrieval-Augmented Generation (RAG) as a required skill
# 2. **Agentic AI Focus**: Several roles emphasize building AI agents and multi-agent systems
# 3. **Cloud Platform Integration**: AWS, Azure, and GCP experience with specific AI services (Bedrock, Vertex AI, OpenAI)
# 4. **Python Dominance**: Python is universally required across all positions
# 5. **Hybrid Options Available**: While many are fully remote, some hybrid positions exist in tech hubs
#
# ## **Salary Ranges:**
# - Entry-level: $100K - $120K
# - Mid-level: $120K - $200K
# - Senior-level: $150K - $240K+
# - Specialized/Principal: $200K - $425K+
#
# ## **Recommendations:**
# 1. **Focus on RAG and LLM expertise** - These are the most in-demand skills
# 2. **Highlight Python proficiency** - Essential for all positions
# 3. **Emphasize cloud platform experience** - AWS, Azure, or GCP with their AI services
# 4. **Consider both remote and hybrid** - More opportunities available if open to hybrid arrangements
#
# The market shows strong demand for AI/ML engineers with your specific skill set, particularly those with hands-on experience in productionizing LLM applications with RAG architectures.
# ================================== Ai Message ==================================
#
# Based on my analysis of Vegashkar's resume and current industry trends, here's a comprehensive assessment:
#
# ## **Latest Things Vegashkar Must Learn (Based on Resume Analysis & Industry Trends)**
#
# ### **1. Advanced MLOps & Production Engineering**
# - **Kubernetes for AI workloads** - His resume shows Docker experience but needs Kubernetes expertise
# - **Model monitoring tools** - MLflow, Weights & Biases, Evidently AI
# - **CI/CD for ML pipelines** - Automated testing and deployment workflows
#
# ### **2. Small Language Models (SLMs)**
# - **Microsoft Phi-3.5, Meta Llama 4** - Industry shifting from large LLMs to efficient SLMs
# - **Model fine-tuning techniques** - LoRA, QLoRA for parameter-efficient fine-tuning
# - **SLM deployment optimization** - Model compression and quantization
#
# ### **3. Advanced RAG 2.0+ Systems**
# - **Multi-modal RAG** - Combining text, images, and audio retrieval
# - **Real-time knowledge updates** - Dynamic vector database management
# - **Advanced retrieval techniques** - Hybrid search, re-ranking models
#
# ### **4. AI Agent Frameworks**
# - **AutoGen** - Microsoft's multi-agent conversation framework
# - **Agent orchestration patterns** - Advanced LangGraph workflows
# - **Tool-calling optimization** - Better integration with external APIs
#
# ### **5. Cloud AI Services**
# - **AWS Bedrock** - Managed foundation models service
# - **Azure AI Foundry** - End-to-end AI development platform
# - **Google Vertex AI** - Unified ML platform
#
# ### **6. Edge AI & On-Device Deployment**
# - **Model quantization techniques** - INT8, FP16 optimization
# - **Mobile AI frameworks** - TensorFlow Lite, Core ML
# - **Federated learning** - Privacy-preserving distributed training
#
# ### **7. AI Ethics & Governance**
# - **Bias detection frameworks** - Fairlearn, AI Fairness 360
# - **Model explainability** - SHAP, LIME for LLMs
# - **AI safety practices** - Alignment techniques for generative AI
#
# ### **8. Specialized Domain Knowledge**
# - **Financial AI applications** - Given his Bountiful AI project
# - **Healthcare AI compliance** - HIPAA, GDPR for AI systems
# - **Enterprise AI integration** - API management, security best practices
#
# ## **10 Latest Jobs Vegashkar Can Search Next**
#
# ### **1. AI Engineer at kadence**
# - **Why suitable**: Matches his LangGraph, agentic workflows experience
# - **Skills match**: 90% - Strong in Python, LLMs, RAG, agentic AI
# - **Salary**: $150K-$180K/yr
#
# ### **2. GenAI and Agentic AI Engineer at Arbitration Forums, Inc.**
# - **Why suitable**: Direct match with his CrewAI and agentic systems experience
# - **Skills match**: 85% - RAG, prompt engineering, Azure AI
# - **Salary**: $128K-$195K/yr
#
# ### **3. Senior Engineer II - AI/ML at Fanatics**
# - **Why suitable**: AWS Bedrock experience would complement his Azure background
# - **Skills match**: 80% - Python, LLMs, real-time analytics
# - **Salary**: $128K-$242K/yr
#
# ### **4. AI/ML VertexAI Engineer at AMISEQ**
# - **Why suitable**: Opportunity to expand cloud expertise to GCP
# - **Skills match**: 75% - Python, model deployment, cloud platforms
# - **Salary**: Competitive (market rate)
#
# ### **5. AI Engineer at Powerfront**
# - **Why suitable**: Perfect match with his vector database and RAG experience
# - **Skills match**: 90% - Vector DBs, Graph DBs, RAG, Python
# - **Salary**: Competitive
#
# ### **6. Senior AI Engineer at Syndio**
# - **Why suitable**: Context engineering aligns with his preference-alignment work
# - **Skills match**: 85% - LLM applications, API integrations
# - **Salary**: $157K-$185K/yr
#
# ### **7. AI Engineer - LLMs, Agents & RAG at EY**
# - **Why suitable**: Enterprise AI experience would build on his current role
# - **Skills match**: 90% - Azure OpenAI, LangChain, vector search
# - **Location**: On-site (Nashville)
#
# ### **8. AI/ML Engineer at ReturnPro**
# - **Why suitable**: Generative AI focus matches his recent projects
# - **Skills match**: 95% - RAG, AI agents, LLMs, LangChain
# - **Location**: On-site (Miami)
#
# ### **9. Machine Learning Engineer at Hirenza**
# - **Why suitable**: Broader ML role to complement his AI specialization
# - **Skills match**: 80% - Python, ML algorithms, statistical modeling
# - **Salary**: Competitive
#
# ### **10. AI/ML Engineer at micro1**
# - **Why suitable**: AWS focus to diversify his cloud expertise
# - **Skills match**: 85% - Python, LLMs, RAG, AWS
# - **Salary**: Competitive
#
# ## **Recommended Learning Path:**
#
# ### **Immediate (1-3 months):**
# 1. Complete Kubernetes certification
# 2. Build a project with Microsoft Phi-3.5 SLM
# 3. Implement advanced RAG with multi-modal retrieval
#
# ### **Medium-term (3-6 months):**
# 1. AWS Bedrock specialization
# 2. AutoGen framework mastery
# 3. MLOps toolchain implementation
#
# ### **Long-term (6-12 months):**
# 1. Edge AI deployment project
# 2. AI ethics certification
# 3. Domain specialization in fintech or healthcare AI
#
# ## **Application Strategy:**
# 1. **Primary focus**: Remote AI Engineer roles with RAG/LLM focus
# 2. **Secondary focus**: Hybrid roles in tech hubs for career growth
# 3. **Target companies**: Tech companies with strong AI investments
# 4. **Portfolio enhancement**: Add 1-2 projects demonstrating new skills
#
# Vegashkar's current skill set is highly relevant for today's AI job market. With targeted learning in MLOps, SLMs, and advanced RAG systems, he can position himself for senior AI engineering roles with salaries in the $150K-$200K range.

# %% [markdown]
# # Crewai

# %%
from crewai import Crew, Process, Agent
